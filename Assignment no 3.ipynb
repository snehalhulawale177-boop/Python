# %%
# 1] Positive, Negative, Or Zero

# %%
num = int(input("Enter a numbre: "))

if num > 0:
    print("positive ")
elif n<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a numbre:  5
# positive

# %%
# 2] Even / odd and square

# %%
n = int(input("Enter number:"))

if n % 2 == 0:
    print("Even")
else:
    print("Odd")

print("square =",n*n)
# Out:
# Enter number: 4
# Even
# square = 16

# %%
# 3] Largest Number and Equal Check

# %%
a = int(input())
b = int(input())

if a > b:
    print("Larger =",a)
elif b>a:
    print("Larger =",b)
else:
    print("Both are equal")
# Out:
#  10
#  20
# Larger = 20

# %%
# 4] Largest,smallest and Average

# %%
a = int(input())
b = int(input())
c = int(input())

print("Largest =",max(a,b,c))
=print("smallest =",min(a,b,c))
print("Average =",(a+b+c)/3)
# Out:
#  10
#  20
#  30
# Largest = 30
# smallest = 10
# Average = 20.0

# %%
# 5] Marks,Total,Percentage, Grade

# %%
m1 = int(input())
m2 = int(input())
m3 = int(input())
m4 = int(input())
m5 = int(input())

total = m1+m2+m3+m4+m5
per = total/5

if per>=90:
    grade = "A"
elif per >=75:
    grade = "B"
elif per >=50:
    grade= "C"
else:
    grade = "F"

print("Total =",total)
print("percentage =",per)
print("Grade =",grade)
# Out:
#  80
#  90
#  70
#  85
#  75
# Total = 400
# percentage = 80.0
# Grade = B

# %%
# 6] Pass or fail

# %%
marks = [int(input()) for i in range(5)]

if min(marks)>=35:
    print("pass")
else:
    print("fail")
# Out:
#  40
#  50
#  60
#  70
#  80
# pass

# %%
# 7] Leap Year

# %%
year=int(input("Enter year:"))

if(year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    
    print("Leap year")
else:
    print("Not leap year")
# Out:
# Enter year: 2024
# Leap year

# %%
# 8] Vowel,Consonant,Didit or special symbol

# %%
ch = input("Enter character: ")

if ch.isdigit():
    print("Digit")
elif ch.lower() in "aeiou":
    print("Vowel")
elif ch.isalpha():
    print("consonant")
else:
    print("special symbol")
# Out:
# Enter character:  a
# Vowel

# %%
# 9] Uppercase,Lowercase,Digit,Special Character

# %%
ch = input("Enter character:")

if ch.isupper():
    print("Uppercase")
elif ch.islower():
    print("Lowercase")
elif ch.isdigit():
    print("Digit")
else:
    print("special character")
# Out:
# Enter character: A
# Uppercase

# %%
# 10] Divisible by 5, 11, Both or Neither

# %%
n = int(input())

if n % 5 == 0 and n % 11 == 0:
     print("Divisible by both 5 and 11")   
elif n % 5 == 0:
    print("Divisible by 5")
elif n % 11 == 0:
    print("Divisible by 11")
else:
    print("Neither")
# Out:
#  55
# Divisible by both 5 and 11

# %%
# 11] Divisible by 2,3 and 6

# %%
n = int(input())

if n % 2 == 0 and n % 3 == 0:
    print("Divisible by 2,3 and 6")
else:
    print("Not Divisible")
# Out:
#  12
# Divisible by 2,3 and 6

# %%
# 12] Voting, Senior Citizen and Driving Eligibility

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible for voting")
else:
    print("Not Eligible for voting") 

if age >= 60:
    print("senior citizen")

if age >= 18:
    print("Eligible for Driving")
# Out:
# Enter age:  65
# Eligible for voting
# senior citizen
# Eligible for Driving

# %%
# 13] Electricity Bill

# %%
units = int(input())

if units <= 100:
    bill = units * 1.5
elif units <= 200:
    bill = 100*1.5 + (units-100)*2.5
else:
    bill = 100*1.5 + 100*2.5 + (units-200)*4

    print("Bill =", bill)
# Out:
#  250
# Bill = 600.0

# %%
# 14] Income Tax

# %%
income = float(input())

if income <= 250000:
    tax = 0
elif income <= 500000:
    tax = income * 0.05
elif income <= 1000000:
    tax = income * 0.2
else:
    tax = income * 0.3

print("Tax=", tax)
# Out:
#  600000
# Tax= 120000.0

# %%
# 15] Menu Driven Calculator

# %%
a = float(input())
b = float(input())

print("1.Add")
print("2.Sub")
print("3.Mul")
print("4.Div")

ch = int(input())

if ch == 1:
    print(a+b)
if ch == 2:
    print(a-b)
if ch == 3:
    print(a*b)
if ch == 4:
    print(a/b)
# Out:
#  10
#  5
# 1.Add
# 2.Sub
# 3.Mul
# 4.Div
#  1
# 15.0

# %%
# 16] Area of shapes

# %%
ch = int(input())

if ch == 1:
    r = float(input())
    print(3.14*r*r)

elif ch == 2:
    l = float(input())
    b = float(input())
    print(l*b)

elif ch == 3:
    b = float(input())
    h = float(input())
    print(0.5*b*h)

elif ch == 4:
    s = float(input())
    print(s*s)
# Out:
#  1
#  5
# 78.5

# %%
# 17] Check Valid Traingle, Type and Perimeter

# %%
a = float(input("Enter side 1: "))
b = float(input("Enter side 2: "))
c = float(input("Enter side 3: "))

if a+b>c and a+c>b and b+c>a:
    print("valid Traingle")

    if a==b==c:
        print("Equilateral Traingle")
    elif a==b or b==c or a==c:
        print("Isosceles Traingle")
    else:
        print("scalene Traingle")

        perimeter = a+b+c
        print("perimeter =",perimeter)
else:
        print("Invalid Traingle")
# Out:
# Enter side 1:  5
# Enter side 2:  5
# Enter side 3:  5
# valid Traingle
# Equilateral Traingle

# %%
# 18] Check Traingle by Angles

# %%
a = int(input("Enter anngle 1: "))
b = int(input("Enter anngle 2: "))
c = int(input("Enter anngle 3: "))

if a+b+c == 180:
    print("Valid Traingle")

    if a==90 or b==90 or c==90:
        print("Right Triangle")
    elif a<90 and b<90 and c<90:
        print("Acute Triangle")
    else:
        print("Obtuse Triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter anngle 1:  60
# Enter anngle 2:  60
# Enter anngle 3:  60
# Valid Traingle
# Acute Triangle

# %%
# 19] Month Name and Days

# %%
month = int(input("Enter month number (1-12): "))

months=["January","Fabuary","March","April","May","June",

 "July","August","September","October","November","December"]

days=[31,28,31,30,31,30,31,31,30,31,30,31]

if 1 <= month <=12:
    print("month:",months[month-1])
    print("Days:",days[month-1])
else:
    print("Invalid month")
# Out:
# Enter month number (1-12):  6
# month: June
# Days: 30

# %%
# 20] Weekday Name and Type

# %%
day = int(input("Enter weekday number (1-7):"))

week = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]

if 1 <= day <= 7:
    print("Day:",week[day-1])

    if day <= 5:
        print("Weekday")
    else:
        print("Weekend")
else:
    print("Invalid Day")
# Out:
# Enter weekday number (1-7): 6
# Day: Saturday
# Weekend

# %%
# 21] Temperature Classification and conversion

# %%
c = float(input("Enter temprature in celsius:"))

if c < 15:
    print("cold")
elif c < 30:
    print("Normal")
elif c < 40:
    print("Hot")
else:
    print("very Hot")

    f = (c * 9/5) + 32
    print("Fahrenheit =",f)
# Out:
# Enter temprature in celsius: 40
# very Hot
# Fahrenheit = 104.0

# %%
# 22] Password Validation and Strength

# %%
password = input("Enter password:")

has_letter = False
has_digit = False

for ch in password:
    if ch.isalpha():
        has_letter = True
    if ch.isdigit():
         has_digit = True

if has_letter and has_digit:
    print("Valid Password")
else:
    print("Invalid Password")

    if len(password)<6:
        print("Weak")
    elif len(password)<10:
        print("Medium")
    else:
        print("Strong")
# Out:
# Enter password: 5
# Invalid Password
# Weak

# %%
# 23] Product price, Discount and Final price

# %%
price = float(input("Enter product price: "))

if price > 5000:
    discount = 20
elif price > 2000:
    discount = 10
else:
    discount = 5

    final_price = price - (price * discount / 100)

    print("Discount =",discount, "%")
    print("Final price =",final_price)
# Out:
# Enter product price:  3000
# Discount = 5 %
# Final price = 2850.0

# %%
# 24] Employee Salary,Bonus Total Salary

# %%
salary = float(input("Enter salary:"))

if salary > 50000:
    bonus = salary * 0.20
elif salary > 30000:
    bonus = salary * 0.10
else:
    bonus = salary + bonus

    print("Bonus =",bonus)
    print("Total salary =", total)
# Out:
# Enter salary: 40000

# %%
# 25] Even / Odd, Positive / Negative, Greater Than 100

# %%
n = int(input("Enter a number: "))
print("Even" if n%2 == 0 else "odd")
print("positive" if n >= 0 else "Negative")
print("Greater than 100" if n > 100 else "Not Greater than 100")
# Out:
# Enter a number:  120
# Even
# positive
# Greater than 100
