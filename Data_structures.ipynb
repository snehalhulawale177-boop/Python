# %%
# Data structure
# data structure are used to store

# %%
# List
# List is an ordered , mutable (changeable) collection of items

# %%
nums = [10,20,30,40]
type(nums)
# Out:
# list

# %%
# Tuple
# a tuple is an ordered, immutable (not changeable) collection

# %%
t = (10,20,30)
type(t)
# Out:
# tuple

# %%
# Set
# A set is an unordered collection of unique elements

# %%
s = {1,2,3,4,}
type(s)
# Out:
# set

# %%
# Dictionary
# A dictionary stores data in key-value pairs

# %%
student = {
    "name":"Rahul",
    "age":25
}
type(student)
# Out:
# dict

# %%
fruites = ["apple","mango","banana"]

# %%
for fruite in fruites:
    print(fruite)
# Out:
# apple
# mango
# banana

# %%
type(fruites)
# Out:
# list

# %%
self={
    "name":"snehal",
    "age":18
}
type(self)
# Out:
# dict

# %%
# Creating list

# %%
numbers = [1,2,3]

# %%
type(numbers)
# Out:
# list

# %%
numbers = [          ]

# %%
type(numbers)
# Out:
# list

# %%
# string list

# %%
fruites = ["apple","banana","mango"]

# %%
type(fruites)
# Out:
# list

# %%
# mixed list

# %%
mixed = [1,"python",3,5,True]

# %%
mixed
# Out:
# [1, 'python', 3, 5, True]

# %%
type(mixed)
# Out:
# list

# %%
# Accessing Elements

# %%
fruits = ["apple","banana","mango"]

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-1]
# Out:
# 'mango'

# %%
fruits[-2]
# Out:
# 'banana'

# %%
# List slicing

# %%
nums = [10,20,30,40,50]

# %%
nums[1:4]
# Out:
# [20, 30, 40]

# %%
# Element from index 1 to 3

# %%
nums  [1:4]
# Out:
# [20, 30, 40]

# %%
# From begining to index 2

# %%
nums[:3]
# Out:
# [10, 20, 30]

# %%
# from index 2 to end

# %%
nums[2:]
# Out:
# [30, 40, 50]

# %%
# Modifying list elements

# %%
colors = ["red","blue","green"]

# %%
# changing element

# %%
colors[1]="yellow"

# %%
colors
# Out:
# ['red', 'yellow', 'green']

# %%
fruits = ["apple","mango","banana"]

# %%
#changing element

# %%
fruits[1]="orange"

# %%
fruits
# Out:
# ['apple', 'orange', 'banana']

# %%
# Adding elements

# %%
nums = [1,2,3]

# %%
# Adding single at end

# %%
nums.append(4)

# %%
nums
# Out:
# [1, 2, 3, 4]

# %%
nums = [10,20,3,40]

# %%
# adding single at end

# %%
nums.append(50)

# %%
nums
# Out:
# [10, 20, 3, 40, 50]

# %%
#Adding element at specific position

# %%
nums.insert(1, 100)

# %%
nums
# Out:
# [10, 100, 20, 3, 40, 50]

# %%
# Adding multiple elements

# %%
nums.extend([5,6])

# %%
nums
# Out:
# [10, 100, 20, 3, 40, 50, 5, 6]

# %%
# Removing Elements

# %%
nums = [1,2,3,4]

# %%
# remove elements

# %%
nums.remove(3)

# %%
nums
# Out:
# [1, 2, 3]

# %%
nums.pop()
# Out:
# 3

# %%
#deleting using index

# %%
nums = [1,2,3]

# %%
del nums[1]

# %%
nums
# Out:
# [1, 3]

# %%
# remove all elements

# %%
nums.clear()

# %%
nums
# Out:
# []

# %%
# Length of list

# %%
nums = [1,2,3,4]

# %%
len (nums)
# Out:
# 4

# %%
nums = [1,2,3,4]

# %%
for nums in (num):
    print(nums)
# Out:
# 1
# 2
# 3
# 4

# %%
# using for loop

# %%
for fruit in fruits:
    fruit
    print(fruit)
# Out:
# apple
# mango
# banana

# %%
# Sorting lists

# %%
nums = [4,1,3,2]

# %%
# Sort ascending

# %%
nums.sort()

# %%
nums
# Out:
# [1, 2, 3, 4]

# %%
# Sort desending

# %%
nums.sort(reverse=True)

# %%
nums
# Out:
# [4, 3, 2, 1]

# %%
# Reverse List

# %%
nums=[1,2,3,]

# %%
#Reverse the list

# %%
nums.reverse()

# %%
nums
# Out:
# [3, 2, 1]

# %%
#Copying lists

# %%
a=[1,2,3]

# %%
# copying list

# %%
b=a.copy()

# %%
b
# Out:
# [1, 2, 3]

# %%
# Joining lists

# %%
a+b
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
s = [1,2,3,4,5,6,7,]

# %%
max(s)
# Out:
# 7

# %%
min(s)
# Out:
# 1

# %%
sum(s)
# Out:
# 28

# %%
s.count(5)
# Out:
# 1

# %%
s.index(5)
# Out:
# 4

# %%
# creating tuple

# %%
tuple = ()

# %%
tuple
# Out:
# ()

# %%
num = (10,20,30,)

# %%
num
# Out:
# (10, 20, 30)

# %%
num = ("10","20","30")
print(num)
# Out:
# ('10', '20', '30')

# %%
# mixed data type

# %%
mixed =("2","python","5","7","True")
print(mixed)
# Out:
# ('2', 'python', '5', '7', 'True')

# %%
fruits = ["apple","mango","banana"]

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-2]
# Out:
# 'mango'

# %%
fruits[-1]
# Out:
# 'banana'

# %%
nums = [10,20,30,40,50]

# %%
nums[1:4]
# Out:
# [20, 30, 40]

# %%
nums[0:3]
# Out:
# [10, 20, 30]

# %%
nums = [1,2,3,4]

# %%
len(nums)
# Out:
# 4

# %%
9 is (list)
# Out:
# False

# %%
for nums in (num):
    print(nums)
# Out:
# 10
# 20
# 30

# %%
a = [1,2]
b = [3,4]

# %%
a+b
# Out:
# [1, 2, 3, 4]

# %%
a*3
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
b*3
# Out:
# [3, 4, 3, 4, 3, 4]

# %%
a = [10,20,30]

# %%
max(num)
# Out:
# '30'

# %%
min(num)
# Out:
# '10'

# %%
list(num)
# Out:
# ['10', '20', '30']

# %%
num = [1,2,3,4]

# %%
list(num)
# Out:
# [1, 2, 3, 4]

# %%
# Single element tuple

# %%
single = (10)

# %%
single
# Out:
# 10

# %%
single = (20,)

# %%
single
# Out:
# (20,)

# %%
# Tuple slicing

# %%
nums = (10,20,30,40,50)

# %%
# Elements from 1 to 3

# %%
nums[1:4]
# Out:
# (20, 30, 40)

# %%
# from beginning to index 2

# %%
nums[:3]
# Out:
# (10, 20, 30)

# %%
# From index 2 to end

# %%
nums[2:]
# Out:
# (30, 40, 50)

# %%
# Tuple Unpacking

# %%
nums = (1,2,3)

# %%
a,b,c = nums

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
nums = ("True","False")

# %%
s,t = nums

# %%
s
# Out:
# 'True'

# %%
t
# Out:
# 'False'

# %%
message = ("welcome to python programming")

# %%
print(message)
# Out:
# welcome to python programming

# %%
message.lower()
# Out:
# 'welcome to python programming'

# %%
message.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
len(message)
# Out:
# 29

# %%
print("welcome\n to\n python\n programming")
# Out:
# welcome
#  to
#  python
#  programming

# %%
# set create

# %%
s = {1,2,3,4}

# %%
print(s)
# Out:
# {1, 2, 3, 4}

# %%
type(s)
# Out:
# set

# %%
s = {}

# %%
print(s)
# Out:
# {}

# %%
s = {1,2,3,4,5,6,7}

# %%
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
# Add set

# %%
s = {1,2,3,4,5,6}

# %%
s.add(7)

# %%
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s.update([1,2,3,4,5,6,7])

# %%
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s = {1,2,3,4,5,6,7}

# %%
s.remove(5)

# %%
print(s)
# Out:
# {1, 2, 3, 4, 6, 7}

# %%
s.pop()
# Out:
# 1

# %%
s.clear()

# %%
print(s)
# Out:
# set()

# %%
s = {10,5,3,8,77,30,20}

# %%
print(s)
# Out:
# {3, 20, 5, 8, 10, 77, 30}

# %%
print(len(s))
# Out:
# 7

# %%
99 is (set)
# Out:
# False

# %%
set = (1,2,3,4,5,6,7,)

# %%
for set in(set):
    print(set)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
set = {1,13.5,"string",True}

# %%
print(set)
# Out:
# {1, 13.5, 'string'}

# %%
set = {3,13.5,"string",True}

# %%
print(set)
# Out:
# {True, 3, 13.5, 'string'}

# %%
a = {1,2}
b = {3,4}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4}

# %%
a = {1,2,3}
b = {2,3,4}

# %%
a-b
# Out:
# {1}

# %%
a.difference(b)
# Out:
# {1}

# %%
a.symmetric_difference(b)
# Out:
# {1, 4}

# %%
num = {1,2,3,4,5,6,7}

# %%
print(num)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a-b
# Out:
# {1}

# %%
max(num)
# Out:
# 7

# %%
min(num)
# Out:
# 1

# %%
sum(num)
# Out:
# 28

# %%
s = [1,2,3,4,5,6,7]

# %%
print(s)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
# set intersection

# %%
a = {1,2,3}
b = {2,3,4}

# %%
#common elements

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
# using &

# %%
a & b
# Out:
# {2, 3}

# %%
# copying set

# %%
a = {1,2,3}

# %%
#copying set

# %%
b = a.copy()

# %%
b
# Out:
# {1, 2, 3}

# %%
# Nested sets using frozenset()

# %%
# Normal sets cannot contain sets
# Use frozenset for nested sets

# %%
a = frozenset({1,2})

# %%
b = {a,3}

# %%
b
# Out:
# {3, frozenset({1, 2})}

# %%
# frozen set

# %%
# Immutable set

# %%
frozen = frozenset([1,2,3])

# %%
type(frozen)
# Out:
# frozenset

# %%
# creating dictionary

# %%
student = {
    "name":"snehal",
    "age":"18"
}

# %%
type(student)
# Out:
# dict

# %%
teacher = {
    "name":"dinesh",
    "subject":"java"
}

# %%
type(teacher)
# Out:
# dict

# %%
D = {"subject":"java","maraks":"80",}

# %%
print(D)
# Out:
# {'subject': 'java', 'maraks': '80'}

# %%
# mixed datatype dictionary

# %%
mixed = {
    1:"one",
    "name":"python",
    True:100
}

# %%
mixed
# Out:
# {1: 100, 'name': 'python'}

# %%
mixed = {
    2:"two",
    "name":"python",
    True:100
}

# %%
mixed
# Out:
# {2: 'two', 'name': 'python', True: 100}

# %%
student["name"]
# Out:
# 'snehal'

# %%
# Access using get()

# %%
student.get("age")
# Out:
# '18'

# %%
# Adding element

# %%
student = {
    "name":"snehal"
}

# %%
# Add new kay-value pair

# %%
student["age"] = 18

# %%
student
# Out:
# {'name': 'snehal', 'age': 18}

# %%
student["marks"] = 80

# %%
student
# Out:
# {'name': 'snehal', 'age': 18, 'marks': 80}

# %%
student["age"] = 19

# %%
student
# Out:
# {'name': 'snehal', 'age': 19, 'marks': 80}

# %%
# Removing element

# %%
student.popitem()
# Out:
# ('name', 'snehal')

# %%
student
# Out:
# {}

# %%
# Remove all items

# %%
student.clear()

# %%
student
# Out:
# {}

# %%
# Length of dictionary

# %%
student = {
    "name":"snehal",
    "age":"18"

}

# %%
len(student)
# Out:
# 2

# %%
# cheaking keys

# %%
student = {
    "name":"snehal",
    "age":"18"
}

# %%
if "name" in student:
    print("name in the dictionary")
else:
    print("name is not in the dictionary")
# Out:
# name in the dictionary

# %%
for student in student:
    print(student)
# Out:
# name
# age

# %%
# Loop through values

# %%
#copy dictionary

# %%
s = {
    "name":"snehal",
    "age":"18"
}

# %%
s
# Out:
# {'name': 'snehal', 'age': '18'}

# %%
for value in s.values():
    value
    print(value)
# Out:
# snehal
# 18

# %%
s.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
s.values()
# Out:
# dict_values(['snehal', '18'])

# %%
s.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
# common dictionary function

# %%
student = {
    "age":18,
    "marks":90,
    "height":170
}

# %%
# Maximum key

# %%
max(student)
# Out:
# 'marks'

# %%
# Minimum key

# %%
min(student)
# Out:
# 'age'

# %%
# Length of key

# %%
len(student)
# Out:
# 3

# %%
# convert dictionary to list

# %%
student = {
    "name":"snehal",
    "age":18
}

# %%
list(student)
# Out:
# ['name', 'age']

# %%
# Convert the value to list

# %%
list(student.values())
# Out:
# ['snehal', 18]

# %%
# Convert items to list

# %%
list(student.items())
# Out:
# [('name', 'snehal'), ('age', 18)]
