# %%
# integer

# %%
# intiger means whole numbers

# %%
age = 21

# %%
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
marks = 90

# %%
print(marks,type(marks))
# Out:
# 90 <class 'int'>

# %%
temprature = -5

# %%
print(temprature,type(temprature))
# Out:
# -5 <class 'int'>

# %%
# integer operations

# %%
a = 25
b = 10

# %%
# addition

# %%
a+b
# Out:
# 35

# %%
# subtraction

# %%
a-b
# Out:
# 15

# %%
# multiplication

# %%
a*b
# Out:
# 250

# %%
# division

# %%
a/b
# Out:
# 2.5

# %%
# floor division

# %%
a//b
# Out:
# 2

# %%
# reminder

# %%
a%b
# Out:
# 5

# %%
# power

# %%
a**b
# Out:
# 95367431640625

# %%
# string

# %%
# string means text

# %%
First_name = "Snehal"
Last_name = "hulawale"
Course = "python"

# %%
print("First_name",type(First_name))
# Out:
# First_name <class 'str'>

# %%
print("first_name",type(first_name))
# Out:
# first_name <class 'str'>

# %%
#strimg repetition

# %%
word = "python"

# %%
print(word*3)
# Out:
# pythonpythonpython

# %%
word = "python "

# %%
print(word*3)
# Out:
# python python python

# %%
# string indexing

# %%
language = "python"

# %%
language[0]
# Out:
# 'p'

# %%
language[1]
# Out:
# 'y'

# %%
language[-1]
# Out:
# 'n'

# %%
language[-2]
# Out:
# 'o'

# %%
# string slicing

# %%
language = "python programming"

# %%
language[0:6]
# Out:
# 'python'

# %%
language[7:18]
# Out:
# 'programming'

# %%
language[:6]
# Out:
# 'python'

# %%
language[7:]
# Out:
# 'programming'

# %%
language[0:]
# Out:
# 'python programming'

# %%
# string methods

# %%
message = "welcome to python programming"

# %%
message.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
message.lower()
# Out:
# 'welcome to python programming'

# %%
message.title()
# Out:
# 'Welcome To Python Programming'

# %%
message.capitalize()
# Out:
# 'Welcome to python programming'

# %%
len(message)
# Out:
# 29

# %%
# replace
# used to replace a word or character in a string.

# %%
text = "i like java"

# %%
new_text = text.replace("java","python")

# %%
print(new_text)
# Out:
# i like python

# %%
# split
# used to split a string into a list.

# %%
text = "apple banana mango"

# %%
words = text.split()

# %%
print(words)
# Out:
# ['apple', 'banana', 'mango']

# %%
# split with separator

# %%
text = "apple,banana,mango"

# %%
words = text.split(",")

# %%
print(words)
# Out:
# ['apple', 'banana', 'mango']

# %%
# join
# used to join list items into a single string.

# %%
words = ['python','is','easy']

# %%
sentence = " ".join(words)

# %%
print(sentence)
# Out:
# python is easy

# %%
# join with comma

# %%
words = ['Apple','Banana','Mango']

# %%
result = ",".join(words)

# %%
print(result)
# Out:
# Apple,Banana,Mango

# %%
# strip

# %%
# used to remove extra space from the beginning

# %%
text = " python "

# %%
clean_text = text.strip()

# %%
clean_text
# Out:
# 'python'

# %%
# Lstrip remove left spaces

# %%
text = " Hello"

# %%
text.lstrip()
# Out:
# 'Hello'

# %%
# rstrip remove right spaces

# %%
text = "Hello "

# %%
text.rstrip()
# Out:
# 'Hello'

# %%
# string formatting

# %%
# f-strings a modern and easy way to insert variables into strings

# %%
name = "snehal"
age = 18

# %%
print(f"my  name is {name} and i am {age} years old:")
# Out:
# my  name is snehal and i am 18 years old:

# %%
# mathematical operations inside f-string

# %%
a = 10
b = 5

# %%
print(f"sum = {a+b}")
# Out:
# sum = 15

# %%
# format

# %%
name = "snehal"
age = 18

# %%
print("my name is{}and I am {} years old.".format(name,age))
# Out:
# my name issnehaland I am 18 years old.

# %%
# Boolean

# %%
# Boolean has only two values:True and false

# %%
is_student = True
is_employed = False

# %%
print(is_student, type(is_student))
# Out:
# True <class 'bool'>

# %%
print(is_employed,type(is_employed))
# Out:
# False <class 'bool'>

# %%
# Boolean with comparisions

# %%
age = 18

# %%
age >= 18
# Out:
# True

# %%
age < 18
# Out:
# False

# %%
age == 18
# Out:
# True

# %%
age != 18
# Out:
# False

# %%
# Boolean with conditions

# %%
marks = 85

# %%
if marks >= 35:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
# Complex number

# %%
# Complex number has real and imaginary parts

# %%
num = 4 + 5j

# %%
num
# Out:
# (4+5j)

# %%
type(num)
# Out:
# complex

# %%
# Real part

# %%
num.real
# Out:
# 4.0

# %%
# Imaginary part

# %%
num.imag
# Out:
# 5.0

# %%
# Complex number operations

# %%
a = 2 + 3j
b = 4 + 5j

# %%
# Addition

# %%
a + b
# Out:
# (6+8j)

# %%
# Subtraction

# %%
a - b
# Out:
# (-2-2j)

# %%
# Multiplication

# %%
a * b
# Out:
# (-7+22j)

# %%
# Division

# %%
a / b
# Out:
# (0.5609756097560976+0.0487804878048781j)

# %%
# Type conversion

# %%
num = 10

# %%
float(num)
# Out:
# 10.0

# %%
str(num)
# Out:
# '10'

# %%
complex(num)
# Out:
# (10+0j)
