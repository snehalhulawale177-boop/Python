# %%
# function

# %%
# a function is a block of reusable code that performs specific task

# %%
# Built-in functions
# functions already provided by python

# %%
print("Hello")
# Out:
# Hello

# %%
len("python")
# Out:
# 6

# %%
type(10)
# Out:
# int

# %%
# user-defined functions

# %%
# simple function

# %%
def greet():
    print("Hello world")

greet()
# Out:
# Hello world

# %%
def greet():
    print("Hi snehal")

greet()
# Out:
# Hi snehal

# %%
# function with parameter

# %%
def greet(name):
    print("hello",name)

greet("snehal")
# Out:
# hello snehal

# %%
def greet(name):
    print(name)

greet(3)
# Out:
# 3

# %%
def greet(number):
    print(number)

greet(7)
# Out:
# 7

# %%
def greet(name,age):
    print(name,age)

greet("snehal",18)
# Out:
# snehal 18

# %%
# function with return value

# %%
def add(a, b):
    return a+b

result = add(10,20)
print(result)
# Out:
# 30

# %%
def add(s, t):
    return s+t
    
result = add(50,70)
print(result)
# Out:
# 120

# %%
def mul(a, b):
    return a*b

result = mul(10,20)
print(result)
# Out:
# 200

# %%
def add(a, b): 
    add = a+b
    mul = a*b
    return(add+mul)

result =add(10,10)
print(result)
# Out:
# 120

# %%
# default parameter

# %%
def greet(name="user"):
    print("hello",name)

greet()
greet("snehal")
# Out:
# hello user
# hello snehal

# %%
def greet(sub="python"):
    print(f"I like {sub} programming")

greet()
greet("java")
# Out:
# I like python programming
# I like java programming

# %%
#multiple parameters

# %%
def student(name,age):
    print("Name:",name)
    print("Age:",age)

student("snehal",18)
# Out:
# Name: snehal
# Age: 18

# %%
# Types of argument

# %%
# positional arguments

# %%
def show(name,age):
    print(name,age)

show("snehal",18)
# Out:
# snehal 18

# %%
def show(name,age):
    print(name,age)

show("snehal",18)
# Out:
# snehal 18

# %%
print(f"my name is {name} and i am {age} years old.")
# Out:
# my name is snehal and i am 18 years old.

# %%
print(f" i am {age} years old and my name is {name}.")
# Out:
#  i am 18 years old and my name is snehal.

# %%
# keyword arguments

# %%
def show(name,age,):
    print(name,age,)

show(,age=18,name="snehal")
# Out:
#   Cell In[3], line 4
#     show(,age=18,name="snehal")
#          ^
# SyntaxError: invalid syntax

# %%
print(f"my name is{name} and marks is {marks} and i am {age} years old.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 print(f"my name is{name} and marks is {marks} and i am {age} years old.")
#
# NameError: name 'marks' is not defined

# %%
def info(**data):
    print(data)

info(name="snehal",age=18)
# Out:
# {'name': 'snehal', 'age': 18}

# %%
# * args (multiple values)

# %%
def add(*nums):
    print(sum(nums))

add(10,20,30)
# Out:
# 60

# %%
def mul (*arg):
    mul = 1
    for number in arg:
        mul*=number
    return mul

mul(10,20,30)
# Out:
# 6000

# %%
# lambda function (Anonymous function)

# %%
add = lambda a,b: a + b

print(add(10,20))
# Out:
# 30
