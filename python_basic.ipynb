# %%
# variables

# %%
# a variable is a name used to store data

# %%
student_name = "Snehal"

# %%
print(student_name)
# Out:
# Snehal

# %%
student_age = 21

# %%
print(student_age)
# Out:
# 21

# %%
student_marks = 81.65

# %%
print(student_marks)
# Out:
# 81.65

# %%
# printing with labels

# %%
name = "Snehal"

# %%
print("name:",name)
# Out:
# name: Snehal

# %%
age = 21

# %%
print("age:",age)
# Out:
# age: 21

# %%
city = "pune"

# %%
print("city:",city)
# Out:
# city: pune

# %%
# changing variable values

# %%
course = "python"

# %%
print("before changing:",course)
# Out:
# before changing: python

# %%
course = "data science"

# %%
print("after changing:",course)
# Out:
# after changing: data science

# %%
# multiple variables

# %%
x,y,z = 100,200,300

# %%
print("x =",x)
# Out:
# x = 100

# %%
print("y =",y)
# Out:
# y = 200

# %%
print("z =",z)
# Out:
# z = 300

# %%
# same value to multiple variables

# %%
maths = science = english = 90

# %%
print("maths:",maths)
# Out:
# maths: 90

# %%
print("science:",science)
# Out:
# science: 90

# %%
print("english:",english)
# Out:
# english: 90

# %%
# invalid variable names

# %%
2name = "Snehal"
# Out:
#   Cell In[32], line 1
#     2name = "Snehal"
#     ^
# SyntaxError: invalid decimal literal

# %%
student-name = "snehal"
# Out:
#   Cell In[33], line 1
#     student-name = "snehal"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
full name = "snehal S"
# Out:
#   Cell In[34], line 1
#     full name = "snehal S"
#          ^
# SyntaxError: invalid syntax

# %%
class = "python"
# Out:
#   Cell In[35], line 1
#     class = "python"
#           ^
# SyntaxError: invalid syntax

# %%
# Dynamic Typing

# %%
# python automatically understands the data type

# %%
value = 100

# %%
print(value)
# Out:
# 100

# %%
print(type(value))
# Out:
# <class 'int'>

# %%
value = "python"

# %%
print(value)
# Out:
# python

# %%
print(type(value))
# Out:
# <class 'str'>

# %%
value = 45.75

# %%
print(value)
# Out:
# 45.75

# %%
print(type(value))
# Out:
# <class 'float'>

# %%
# common escape character

# %%
# escape character are special (starting with / ) used to add formattting

# %%
print("i like python programming")
# Out:
# i like python programming

# %%
print("Hello\nworld")
# Out:
# Hello
# world

# %%
# Backslash- \\

# %%
print("c:\\users\\snehal")
# Out:
# c:\users\snehal

# %%
# Single quote - \'
# used when string is inside double quotes

# %%
print('It\'s python')
# Out:
# It's python

# %%
# Double quote - \'

# %%
print("He said \"Hello\"")
# Out:
# He said "Hello"

# %%
# Unicode character

# %%
print("\u0041")
# Out:
# A

# %%
print("\u0939")
# Out:
# ह

# %%
#print()function
# It is used to display output on the screen.

# %%
# printing text

# %%
print("hello world")
# Out:
# hello world

# %%
# printing variables

# %%
name = "snehal"
print(name)
# Out:
# snehal

# %%
# printing multiple values

# %%
name = "snehal"
age = 18

# %%
print(name,age)
# Out:
# snehal 18

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
