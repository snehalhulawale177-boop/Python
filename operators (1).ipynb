# %%
# Arithmetic operator

# %%
a = 10
b = 3

# %%
# Addition

# %%
a + b
# Out:
# 13

# %%
# substraction

# %%
a - b
# Out:
# 7

# %%
# Multiplication

# %%
a * b
# Out:
# 30

# %%
#modules

# %%
a % b
# Out:
# 1

# %%
# Division

# %%
a / b
# Out:
# 3.3333333333333335

# %%
# floor division

# %%
a // b
# Out:
# 3

# %%
# comparison operators

# %%
x = 5
y = 10

# %%
# equal to

# %%
x == y
# Out:
# False

# %%
# not equai to

# %%
x != y
# Out:
# True

# %%
# greater than

# %%
x > y
# Out:
# False

# %%
# less than

# %%
x < y
# Out:
# True

# %%
# greater than equal to

# %%
x >= y
# Out:
# False

# %%
# less than equal to

# %%
x <= y
# Out:
# True

# %%
# logical operators

# %%
# and : return true only if bothcondition are true.
# or : return true if at least one condition  is true.
# not : return true result , inverting true or false and vice versa.

# %%
a = True
b = False

# %%
# And

# %%
a and b
# Out:
# False

# %%
# Or

# %%
a or b
# Out:
# True

# %%
# Not

# %%
not a
# Out:
# False

# %%
# Assignment operators

# %%
x = 5

# %%
x + 5
# Out:
# 10

# %%
x - 5
# Out:
# 5

# %%
x = x-5

# %%
print(x)
# Out:
# 5

# %%
# x = x=3

# %%
x +=3

# %%
x
# Out:
# 8

# %%
# x = x-2

# %%
x -=2

# %%
x
# Out:
# 6

# %%
# x = x*4

# %%
x *=4

# %%
x
# Out:
# 24

# %%
# x = x/5

# %%
x /=5

# %%
x
# Out:
# 4.8

# %%
# membership operators

# %%
fruits = ["apple","banana","mango"]

# %%
"apple" in fruits
# Out:
# True

# %%
"grapes" not in fruits
# Out:
# True

# %%
# Identity operators

# %%
a = [1,2,3]
b = a
c = [1,2,3]

# %%
# True

# %%
a is b
# Out:
# True

# %%
# False

# %%
a is c
# Out:
# False

# %%
# True

# %%
a is not c
# Out:
# True

# %%
# Bitwise operators

# %%
a = 5 
b = 3

# %%
# AND

# %%
a & b
# Out:
# 1

# %%
# OR

# %%
a | b
# Out:
# 7

# %%
# XOR

# %%
a ^ b
# Out:
# 6

# %%
# NOT

# %%
~a
# Out:
# -6

# %%
# Left shift 1

# %%
a << 1
# Out:
# 10

# %%
# Right sift

# %%
a >> 1
# Out:
# 2
